# %%
words = open('names.txt', 'r').read().splitlines()
words[:5]
# Out:
# ['emma', 'olivia', 'ava', 'isabella', 'sophia']

# %%
for w in words[:5]:
    for ch1,ch2 in zip(w, w[1:]):
        print(ch1,ch2)
